SotoMayor= Polygon(coords14)
Victoria= Polygon(coords15)
Yungay= Polygon(coords16)
AnibalPinto= Polygon(coords17)
CarlosVonMoltke= Polygon(coords18)
EleuterioRamirez= Polygon(coords19)
JoaquinEdwardsBello= Polygon(coords20)
LordCochrane= Polygon(coords21)
Mena= Polygon(coords22)
SalvadorAllende= Polygon(coords23)
SanFranciscoDeAsis= Polygon(coords24)
Weddington= Polygon(coords25)
SanMartin= Polygon(coords26)

#Se crea un objeto GeoDataFrame con GeoPandas y se establece una columna "nombre" y otra con la geometría (que es
#Polígono). Luego se establece la proyección de coordendas a "EPSG:4326".
gdf = gpd.GeoDataFrame(
    {"nombre": ["Plaza Bismarck", "Plaza Blanco Encalada", "Plaza Cívica" , "Plaza De La Conquista" , 
                "Plaza Echaurren" , "Plaza Esmeralda" , "Plaza O'Higgins" , "Plaza Pajaritos" , "Plaza Radomiro Tomic" , 
                "Plaza Santa Margarita" , "Plaza Santiago Severín" , "Plaza Santiago Wanderers" , "Plaza Simón Bolivar",
               "Plaza SotoMayor", "Plaza Victoria","Plaza Yungay", "Plaza Anibal Pinto" , "Plaza Carlos von Moltke", 
                "Plaza Eleuterio Ramírez", "Plaza Joaquín Edwards Bello", "Plaza Lord Cochrane", "Plaza Mena", 
                "Plaza Salvador Allende", "Plaza San Francisco de Asis","Plaza Weddington" ,"Plaza San Martín"]},
    geometry=[Bismarck, BlancoEncalada, Civica, DeLaConquista ,Echaurren , Esmeralda,Ohiggins ,Pajaritos ,RadomiroTomic , 
              SantaMaria, SantiagoSeverin,SantiagoWanderers ,SimonBolivar, SotoMayor,Victoria , Yungay, AnibalPinto, 
              CarlosVonMoltke, EleuterioRamirez,JoaquinEdwardsBello ,LordCochrane ,Mena ,SalvadorAllende , SanFranciscoDeAsis,
             Weddington, SanMartin],
    crs=CRS("EPSG:4326")
)

#Se convierte el objeto gdf a la proyección "EPSG:3857" y se guarda en un archivo geoJSON llamado "plazas.geojson".
gdf_meters = gdf.to_crs("EPSG:3857")
gdf_meters.to_file("plazas.geojson", driver="GeoJSON")


#Se lee el archivo geoJSON creado anteriormente y crea una lista de áreas de los polígonos en metros cuadrados.
poligonos_meters = gpd.read_file("plazas.geojson")
areas_meters = [poligono.area for poligono in poligonos_meters["geometry"]]


#Se ordenan los polígonos de mayor a menor área
poligonos_sorted = sorted(zip(poligonos_meters["nombre"], areas_meters), key=lambda x: x[1], reverse=True)

#Se imprimen las áreas de los polígonos ordenados de mayor a menor
for i,(nombre, area) in enumerate(poligonos_sorted):
    print(f"El área de la {nombre} es {area} metros cuadrados.")
# Out:
# El área de la Plaza Victoria es 7465.7229445306575 metros cuadrados.
# El área de la Plaza Weddington es 6676.394220185796 metros cuadrados.
# El área de la Plaza Simón Bolivar es 5677.503578837937 metros cuadrados.
# El área de la Plaza Yungay es 3520.2185111612534 metros cuadrados.
# El área de la Plaza Esmeralda es 3322.053880756186 metros cuadrados.
# El área de la Plaza Mena es 3258.4654975116296 metros cuadrados.
# El área de la Plaza Bismarck es 2688.884598232517 metros cuadrados.
# El área de la Plaza Lord Cochrane es 2049.36539375427 metros cuadrados.
# El área de la Plaza Radomiro Tomic es 2035.5114250896054 metros cuadrados.
# El área de la Plaza Carlos von Moltke es 1882.8065326630244 metros cuadrados.
# El área de la Plaza Echaurren es 1597.8976020295281 metros cuadrados.
# El área de la Plaza O'Higgins es 1503.315334740888 metros cuadrados.
# El área de la Plaza Santiago Wanderers es 864.9365153127684 metros cuadrados.
# ...
